# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hussainnawaz21-fail/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !pwd
# !ls
# Out:
# /content/flyrank-ml-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
# !git clone https://github.com/hussainnawaz21-fail/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 133 (delta 45), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 1.85 MiB | 10.51 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# %cd /content/flyrank-ml-internship
# !ls
# Out:
# /content/flyrank-ml-internship
# AGENTS.md    docs		    notebooks	      scripts	  work
# CLAUDE.md    flyrank-ml-internship  outputs	      SETUP.md
# data	     GUIDE.md		    README.md	      skills
# DATA_USE.md  LICENSE		    requirements.txt  submission

# %%
# !head -40 skills/README.md
# Out:
# # Skills — the router
#
# This folder is a small library of **skills**: focused instruction files your AI assistant loads
# one at a time. One skill per task keeps the assistant sharp — its context window is small, and
# filling it with everything makes it worse at the one thing you need.
#
# **How to use it (repo-reading agents — Claude Code, Cursor, Codex):** they find this file
# automatically via `AGENTS.md` / `CLAUDE.md`. Just tell your assistant which task you're doing.
#
# **Using a chat-only assistant (ChatGPT / Gemini in a browser)?** Open the skill file on GitHub,
# copy its whole content, and paste it into your chat before asking for help. That's it.
#
# ## The table — find your task, load ONE skill
#
# | Your task | Load this skill | Also load for data work |
# |---|---|---|
# | Any task — how to work with your assistant at all | `directing-your-ai-assistant/SKILL.md` | — |
# ...

# %%
# !cat skills/framing-ml-problems/SKILL.md
# Out:
# ---
# name: framing-ml-problems
# description: Frames a data/ML problem before any modeling — the decision, the action, the cost of a wrong call, task type, target, and success metric. Use when picking a project direction, writing a research question, or mapping a problem onto an ML task type.
# ---
#
# # Framing ML problems
#
# A model is never the goal. A better DECISION is the goal. Frame first, model later.
#
# ## The four questions (answer all four, in writing)
#
# 1. **What decision does this improve?** Not "predict X" — decisions. "Which page should an
#    editor fix first?" is a decision. "Predict decline" is not, yet.
# 2. **Who acts on the output, and what do they do?** Name the person and the action. If nobody
#    would act differently, the work has no customer.
# 3. **What does a wrong answer cost?** Wasted editor hours? A missed decline? The cost of errors
#    decides how careful the method must be, and which errors matter more.
# ...

# %%
# !cat skills/flyrank/flyrank-data/SKILL.md
# Out:
# ---
# name: flyrank-data
# description: The FlyRank internship datasets — the 30k-row starter CSV and its gotchas, the ~79M-row warehouse release tables and grains, panel warnings, access, and iteration rules. Load for EVERY task that touches the data. (Project-specific: delete this folder when reusing the skill library elsewhere.)
# ---
#
# # FlyRank internship data
#
# Two datasets. The small one ships in this repo; the big one is hosted and gated.
#
# ## 1. Starter dataset (in this repo)
#
# `data/raw/content_refresh_anonymized.csv` — 30,000 rows × 44 columns, one row per pseudonymized
# content item, 32 clients, trailing-90-day metrics. Full column reference: `docs/data-dictionary.md`
# (keep it open). The gotchas that cause 90% of mistakes:
#
# - **Rate columns are ×100 percentages**: `ctr = 0.76` means 0.76%, not 76%. Applies to ctr,
#   engagement_rate, scroll_rate, ai_traffic_pct, trend_pct.
# - **`avg_position = 0` means "no data"**, not rank zero (1,205 rows).
# ...

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# First 5 rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# ...

# %% [markdown]
# ## 1. My lane as an ML task (type)

# %% [markdown]
# ## Task Type: Ranking
#
# My chosen lane is Content Refresh Prioritization. The goal is to rank content pages based on how urgently they should be refreshed. Instead of simply deciding whether a page needs updating, the model should prioritize pages from highest to lowest refresh priority so that editors know which pages to update first. This is a ranking problem because the output is an ordered list rather than a simple yes/no prediction.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Load the dataset
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Show columns related to ranking the content
ranking_columns = [
    "content_id",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "days_since_last_update",
    "trend_direction",
    "trend_pct"
]

df[ranking_columns].head()
# Out:
#              content_id  impressions_90d  clicks_90d  sessions_90d  \
# 0  content_304f48230142             3803          29            17
# 1  content_a1fb4e703a9e            15320           7             9
# 2  content_9aa793d4d895            12581          11            11
# 3  content_331d6c4de07b            11751          58            78
# 4  content_d99b7a2d90ca            19140          24           145
#
#    days_since_last_update trend_direction  trend_pct
# 0                      20            down      -41.4
# 1                      25            down      -57.7
# 2                      20            down      -60.9
# 3                      22          stable      -13.8
# 4                      14            down      -34.7

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or Proxy
#
# The starter dataset does not contain a direct "refresh priority" label. Instead, we use observed proxy signals such as trend percentage, trend direction, impressions, clicks, sessions, and days since the last update to estimate which content pages should be refreshed first. These measured performance indicators help support the ranking of content based on refresh need.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Load the dataset
proxy_columns = [
    "content_id",
    "trend_direction",
    "trend_pct",
    "days_since_last_update",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d"
]

df[proxy_columns].head()
# Out:
#              content_id trend_direction  trend_pct  days_since_last_update  \
# 0  content_304f48230142            down      -41.4                      20
# 1  content_a1fb4e703a9e            down      -57.7                      25
# 2  content_9aa793d4d895            down      -60.9                      20
# 3  content_331d6c4de07b          stable      -13.8                      22
# 4  content_d99b7a2d90ca            down      -34.7                      14
#
#    impressions_90d  clicks_90d  sessions_90d
# 0             3803          29            17
# 1            15320           7             9
# 2            12581          11            11
# 3            11751          58            78
# 4            19140          24           145

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success Metric
#
# The success metric is Precision@K because the goal is to recommend the most important content pages for refresh. A good result means that most of the top-ranked pages truly need attention, allowing editors to focus on the highest-priority content first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Total content pages:", len(df))

print("\nTop 10 pages with the largest negative trend:")
df.nsmallest(10, "trend_pct")[
    ["content_id", "trend_pct", "trend_direction"]
]
# Out:
# Total content pages: 30000
#
# Top 10 pages with the largest negative trend:
#                content_id  trend_pct trend_direction
# 23   content_2da6ae9d0882     -100.0            down
# 39   content_4595e8704e07     -100.0            down
# 48   content_326fa2fa449f     -100.0            down
# 49   content_f0717373e86e     -100.0            down
# 51   content_d8a23b5e10c5     -100.0            down
# 67   content_9042a5355ff7     -100.0            down
# 68   content_6bc2ec5f6061     -100.0            down
# 111  content_46eaff5b4ae8     -100.0            down
# 130  content_27682a7cd588     -100.0            down
# 141  content_0af426466565     -100.0            down

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## Unit of Analysis
#
# The unit of analysis is one content item (one content page). Each row in the dataset represents a single content page with its search metrics, engagement metrics, content characteristics, and performance over the last 90 days. This allows us to compare pages and decide which ones should be refreshed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Dataset Shape:", df.shape)

print("\nOne row represents one content item.")

display(df.head())
# Out:
# Dataset Shape: (30000, 44)
#
# One row represents one content item.
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML beats a fixed rule
#
# A simple rule such as "refresh content older than 365 days" cannot capture the full picture because content performance depends on multiple signals working together, including trend percentage, impressions, clicks, sessions, engagement, and content age. These patterns are complex and change over time. A machine learning model can learn from these combined signals to produce a better ranking of refresh priority, helping editors make more informed decisions than a single fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
rule_based = df[df["days_since_last_update"] > 365]

print("Pages older than 365 days:", len(rule_based))

print("\nSample pages:")
display(
    rule_based[
        [
            "content_id",
            "days_since_last_update",
            "trend_pct",
            "impressions_90d",
            "clicks_90d"
        ]
    ].head()
)
# Out:
# Pages older than 365 days: 5
#
# Sample pages:
#                  content_id  days_since_last_update  trend_pct  \
# 4606   content_3f3576c295f5                     373        NaN
# 18440  content_8d56efff1e71                     372        NaN
# 24216  content_1b4ec72dafd4                     372     -100.0
# 26242  content_55a5b1c46474                     373      -88.5
# 29384  content_f6fdf87348f6                     373     -100.0
#
#        impressions_90d  clicks_90d
# 4606                 1           1
# 18440                1           0
# 24216                2           0
# 26242               35           0
# 29384                2           0

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
