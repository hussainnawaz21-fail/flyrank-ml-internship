# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/hussainnawaz21-fail/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My Lane
#
# I chose the **Content Refresh Prioritization** lane because websites contain many pages, and it is difficult to know which pages should be updated first. Using data and machine learning can help identify pages that are more likely to need refreshing. This can save time and help SEO teams focus on the pages that matter most.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Decision, Action, and Cost
#
# **Decision:** Decide which website pages should be refreshed first.
#
# **Action:** The SEO or content team updates the pages that the model recommends.
#
# **Cost of a wrong recommendation:** If the model recommends the wrong pages, time and effort may be wasted on pages that do not need updates, while important declining pages may be ignored. This could reduce website traffic and business opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ### Quick Look at the Data
#
# The starter dataset contains **30,000 rows** and **44 columns**. The average CTR is **0.511**, while the average search position is **16.34**. The largest group of pages has a **down** trend (16,262 pages), suggesting that many pages in the dataset may benefit from content refresh. These observations support my choice of the Content Refresh Prioritization lane.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total rows:", len(df))
print("Total columns:", len(df.columns))

print("\nAverage CTR:", round(df["ctr"].mean(), 3))
print("Average Position:", round(df["avg_position"].mean(), 2))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Total rows: 30000
# Total columns: 44
#
# Average CTR: 0.511
# Average Position: 16.34
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful Words
#
# My work can identify patterns in this dataset that may help prioritize which pages should be refreshed first. It can support decision-making, but it cannot prove that one factor directly causes another or predict Google's algorithm. Any conclusions are observations from this dataset only.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
